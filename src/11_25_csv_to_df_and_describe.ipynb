# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\samue\\Documents\\datascientest-lol-draft_analyzer\\src'

# %%
df = pd.read_csv("../draft_data_with_bans.csv")

# %%
print(df.describe())
print(df.info())
print(df.head())
print(df.tail())
print(df.columns)
print(df.shape)
df.dtypes
df.isnull().sum()
df.nunique()
df.sample(5)
# Out:
#        gameDuration  team_100_dragon_kills  team_100_baron_kills  \
# count    696.000000             696.000000            696.000000
# mean    1657.247126               1.622126              0.324713
# std      412.168355               1.305009              0.537266
# min      101.000000               0.000000              0.000000
# 25%     1495.000000               0.000000              0.000000
# 50%     1678.000000               2.000000              0.000000
# 75%     1878.250000               3.000000              1.000000
# max     2942.000000               5.000000              3.000000
#
#        team_100_tower_kills  team_100_inhibitor_kills  \
# count            696.000000                696.000000
# mean               5.662356                  0.826149
# std                3.672110                  1.121384
# min                0.000000                  0.000000
# 25%                2.000000                  0.000000
# ...

# %%
df.describe(include='all').to_excel("describe_complet.xlsx")

# %%
pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\samue\Documents\datascientest-lol-draft_analyzer\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# ...
#      ------------------------------------- 250.9/250.9 KB 16.0 MB/s eta 0:00:00
# ...
